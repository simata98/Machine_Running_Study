# %%
import pandas as pd

# %%
pd.read_csv('data/iphone.csv')
# Out:
#       Unnamed: 0         출시일  디스플레이  메모리     출시 버전 Face ID
# 0       iPhone 7  2016-09-16    4.7  2GB  iOS 10.0      No
# 1  iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# 2       iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No
# 3  iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# 4       iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# 5      iPhone XS  2018-09-21    5.8  4GB  iOS 12.0     Yes
# 6  iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df = pd.read_csv('data/iphone.csv')

# %%
iphone_df
# Out:
#       Unnamed: 0         출시일  디스플레이  메모리     출시 버전 Face ID
# 0       iPhone 7  2016-09-16    4.7  2GB  iOS 10.0      No
# 1  iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# 2       iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No
# 3  iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# 4       iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# 5      iPhone XS  2018-09-21    5.8  4GB  iOS 12.0     Yes
# 6  iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
type(iphone_df)
# Out:
# pandas.core.frame.DataFrame

# %%
iphone_df = pd.read_csv('data/iphone.csv', index_col=0)

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ###  인덱싱하기

# %%
iphone_df.loc['iPhone 8', '메모리']
# Out:
# '2GB'

# %%
iphone_df.loc['iPhone X', :]
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
iphone_df.loc['iPhone X']
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
type(iphone_df.loc['iPhone X'])
# Out:
# pandas.core.series.Series

# %%
iphone_df.loc[:, '출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
iphone_df['출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
iphone_df.loc[['iPhone X', 'iPhone 8']]
# Out:
#                  출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No

# %%
type(iphone_df.loc[['iPhone X', 'iPhone 8']])
# Out:
# pandas.core.frame.DataFrame

# %%
iphone_df[['Face ID', '출시일', '메모리']]
# Out:
#               Face ID         출시일  메모리
# iPhone 7           No  2016-09-16  2GB
# iPhone 7 Plus      No  2016-09-16  3GB
# iPhone 8           No  2017-09-22  2GB
# iPhone 8 Plus      No  2017-09-22  3GB
# iPhone X          Yes  2017-11-03  3GB
# iPhone XS         Yes  2018-09-21  4GB
# iPhone XS Max     Yes  2018-09-21  4GB

# %%
iphone_df.loc[:'iPhone XS']
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[:, '메모리':'Face ID']
# Out:
#                메모리     출시 버전 Face ID
# iPhone 7       2GB  iOS 10.0      No
# iPhone 7 Plus  3GB  iOS 10.0      No
# iPhone 8       2GB  iOS 11.0      No
# iPhone 8 Plus  3GB  iOS 11.0      No
# iPhone X       3GB  iOS 11.1     Yes
# iPhone XS      4GB  iOS 12.0     Yes
# iPhone XS Max  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 7':'iPhoneX', '메모리':'Face ID']
# Out:
#                메모리     출시 버전 Face ID
# iPhone 7       2GB  iOS 10.0      No
# iPhone 7 Plus  3GB  iOS 10.0      No
# iPhone 8       2GB  iOS 11.0      No
# iPhone 8 Plus  3GB  iOS 11.0      No
# iPhone X       3GB  iOS 11.1     Yes
# iPhone XS      4GB  iOS 12.0     Yes
# iPhone XS Max  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[iphone_df['디스플레이']>5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID'] == 'Yes'
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: Face ID, dtype: bool

# %%
(iphone_df['디스플레이']>5) & (iphone_df['Face ID'] == 'Yes')
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# dtype: bool

# %%
condition = (iphone_df['디스플레이']>5) & (iphone_df['Face ID'] == 'Yes')
iphone_df[condition]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ### 위치로 인덱싱

# %%
iphone_df.iloc[2,4]
# Out:
# 'No'

# %%
iphone_df.iloc[[1,3],[1,4]]
# Out:
#                디스플레이 Face ID
# iPhone 7 Plus    5.5      No
# iPhone 8 Plus    5.5      No

# %% [markdown]
# ### 값 쓰기

# %%
iphone_df.loc['iPhone 8', '메모리'] = '2.5GB'

# %%
iphone_df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8'] = ['2016-09-22', '4.7', '2GB', 'IOS 11.0', 'No']

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2016-09-22   4.7  2GB  IOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ### 추가 삭제

# %%
iphone_df.loc['iPhone XR'] = ['2018-10-26', '6.1', '3GB', 'IOS 12.0.1', 'Yes']

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No
# iPhone 8       2016-09-22   4.7  2GB    IOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB    iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes
# iPhone XR      2018-10-26   6.1  3GB  IOS 12.0.1     Yes

# %%
iphone_df['제조사'] = 'Apple'
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2016-09-22   4.7  2GB    IOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB    iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes  Apple
# iPhone XR      2018-10-26   6.1  3GB  IOS 12.0.1     Yes  Apple

# %% [markdown]
# inplace가 False는 값을 바꾸지 않겠다는 뜻이다

# %%
iphone_df.drop('iPhone XR', axis='index', inplace=False)
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2016-09-22   4.7  2GB  IOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2016-09-22   4.7  2GB    IOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB    iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes  Apple
# iPhone XR      2018-10-26   6.1  3GB  IOS 12.0.1     Yes  Apple

# %%
iphone_df.drop('iPhone XR', axis='index', inplace=True)

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2016-09-22   4.7  2GB  IOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple

# %%
iphone_df.rename(columns={'출시일':'Release', '디스플레이':'Display'})
# Out:
#                   Release Display  메모리     출시 버전 Face ID    제조사
# iPhone 7       2016-09-16     4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16     5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2016-09-22     4.7  2GB  IOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22     5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03     5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21     5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21     6.5  4GB  iOS 12.0     Yes  Apple

# %%
iphone_df.index.name = 'Device Name'

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사
# Device Name
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple
# iPhone 8       2016-09-22   4.7  2GB  IOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple

# %%
iphone_df['Device Name'] = iphone_df.index

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사    Device Name
# Device Name
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple       iPhone 7
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple  iPhone 7 Plus
# iPhone 8       2016-09-22   4.7  2GB  IOS 11.0      No  Apple       iPhone 8
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple  iPhone 8 Plus
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple       iPhone X
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple      iPhone XS
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple  iPhone XS Max

# %%
iphone_df.set_index('출시일')
# Out:
#            디스플레이  메모리     출시 버전 Face ID    제조사    Device Name
# 출시일
# 2016-09-16   4.7  2GB  iOS 10.0      No  Apple       iPhone 7
# 2016-09-16   5.5  3GB  iOS 10.0      No  Apple  iPhone 7 Plus
# 2016-09-22   4.7  2GB  IOS 11.0      No  Apple       iPhone 8
# 2017-09-22   5.5  3GB  iOS 11.0      No  Apple  iPhone 8 Plus
# 2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple       iPhone X
# 2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple      iPhone XS
# 2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple  iPhone XS Max

# %%
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID    제조사    Device Name
# Device Name
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No  Apple       iPhone 7
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No  Apple  iPhone 7 Plus
# iPhone 8       2016-09-22   4.7  2GB  IOS 11.0      No  Apple       iPhone 8
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No  Apple  iPhone 8 Plus
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple       iPhone X
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple      iPhone XS
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple  iPhone XS Max

# %%
iphone_df.set_index('출시일', inplace=True)

# %%
iphone_df
# Out:
#            디스플레이  메모리     출시 버전 Face ID    제조사    Device Name
# 출시일
# 2016-09-16   4.7  2GB  iOS 10.0      No  Apple       iPhone 7
# 2016-09-16   5.5  3GB  iOS 10.0      No  Apple  iPhone 7 Plus
# 2016-09-22   4.7  2GB  IOS 11.0      No  Apple       iPhone 8
# 2017-09-22   5.5  3GB  iOS 11.0      No  Apple  iPhone 8 Plus
# 2017-11-03   5.8  3GB  iOS 11.1     Yes  Apple       iPhone X
# 2018-09-21   5.8  4GB  iOS 12.0     Yes  Apple      iPhone XS
# 2018-09-21   6.5  4GB  iOS 12.0     Yes  Apple  iPhone XS Max
